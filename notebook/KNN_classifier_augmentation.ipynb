# %%
import os
import sys
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, PredefinedSplit, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from torchvision.models import resnet50
from torch.utils.data import DataLoader
from torch.utils.data import DataLoader, TensorDataset

from sklearn.model_selection import StratifiedKFold

# Add project path
project_path = os.path.abspath("../code")
sys.path.append(project_path)
from vipm_features import ResNet50FeatureExtractor

project_path = os.path.abspath("../code")  # Adatta il percorso a dove si trova il tuo progetto
sys.path.append(project_path)
project_path = os.path.abspath("../networks")  # Adatta il percorso a dove si trova il tuo progetto
sys.path.append(project_path)
from models import *
from vipm_features import *
import vipm_costants as CONST
from vipm_pipeline import *
from dataset import *
import torch

# Configure environment variable
LOKY_MAX_CPU_COUNT = 16

# %%
# Carica il file CSV
def load_csv(csv_path):
    data = pd.read_csv(csv_path, header=None, names=['image_name', 'label'])
    return data['image_name'].tolist(), data['label'].tolist()

# Carica il file compresso NPZ
def load_features(npz_path):
    data = np.load(npz_path)
    features = data['features']
    labels = data['labels']
    return features, labels

# Percorsi
csv_path_70 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_70_labels.csv'
csv_path_80 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_80_labels.csv'
csv_path_90 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_90_labels.csv'
csv_test = '../dataset/val_info.csv'

indir_70 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_70'
indir_80 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_80'
indir_90 = '../dataset/filtered_small_with_cleaned_retrieval_augmented_90'

test_dir = '../dataset/val_set'
test_degraded_dir = '../dataset/val_set_degraded'

outdir = '../features'  # Modifica in base alla posizione delle feature
os.makedirs(outdir, exist_ok=True)

# Carica le immagini dal CSV
extractor = ResNet50FeatureExtractor()

# Carica le immagini dal CSV 70
image_names_70, labels_70 = load_csv(csv_path_70)
labels_70 = np.array(labels_70)
features_70, _, _ = extractor.get_features(csv=csv_path_70, indir=indir_70, outdir=outdir, normalize=True)

# Carica le immagini dal CSV 80
image_names_80, labels_80 = load_csv(csv_path_80)
labels_80 = np.array(labels_80)
features_80, _, _ = extractor.get_features(csv=csv_path_80, indir=indir_80, outdir=outdir, normalize=True)

# Carica le immagini dal CSV 90
image_names_90, labels_90 = load_csv(csv_path_90)
labels_90 = np.array(labels_90)
features_90, _, _ = extractor.get_features(csv=csv_path_90, indir=indir_90, outdir=outdir, normalize=True)

# Test set 
image_names_test, labels_test = load_csv(csv_test)
labels_test = np.array(labels_test)
features_test, _, _ = extractor.get_features(csv=csv_test, indir=test_dir, outdir=outdir, normalize=True)

# Test set degraded
image_names_test_degraded, labels_test_degraded = load_csv(csv_test)
labels_test_degraded = np.array(labels_test_degraded)
features_test_degraded, _, _ = extractor.get_features(csv=csv_test, indir=test_degraded_dir, outdir=outdir, normalize=True, file_name='features_test_degraded_normalized.npz')
# Out:
# Caricamento delle feature da ../features\filtered_small_with_cleaned_retrieval_augmented_70_labels_resnet50_features_normalized.npz
# Caricamento delle feature da ../features\filtered_small_with_cleaned_retrieval_augmented_80_labels_resnet50_features_normalized.npz
# File non trovato. Estrazione delle feature...
# Elaborazione immagine 1/11971 - Tempo rimanente stimato: 0.00 secondi
# Elaborazione immagine 101/11971 - Tempo rimanente stimato: 309.57 secondi
# Elaborazione immagine 201/11971 - Tempo rimanente stimato: 289.12 secondi
# Elaborazione immagine 301/11971 - Tempo rimanente stimato: 284.93 secondi
# Elaborazione immagine 401/11971 - Tempo rimanente stimato: 279.72 secondi
# Elaborazione immagine 501/11971 - Tempo rimanente stimato: 277.06 secondi
# Elaborazione immagine 601/11971 - Tempo rimanente stimato: 276.24 secondi
# Elaborazione immagine 701/11971 - Tempo rimanente stimato: 276.30 secondi
# Elaborazione immagine 801/11971 - Tempo rimanente stimato: 275.31 secondi
# Elaborazione immagine 901/11971 - Tempo rimanente stimato: 273.78 secondi
# Elaborazione immagine 1001/11971 - Tempo rimanente stimato: 270.85 secondi
# Elaborazione immagine 1101/11971 - Tempo rimanente stimato: 268.41 secondi
# Elaborazione immagine 1201/11971 - Tempo rimanente stimato: 264.88 secondi
# Elaborazione immagine 1301/11971 - Tempo rimanente stimato: 261.45 secondi
# Elaborazione immagine 1401/11971 - Tempo rimanente stimato: 258.94 secondi
# Elaborazione immagine 1501/11971 - Tempo rimanente stimato: 256.13 secondi
# Elaborazione immagine 1601/11971 - Tempo rimanente stimato: 252.86 secondi
# Elaborazione immagine 1701/11971 - Tempo rimanente stimato: 249.50 secondi
# Elaborazione immagine 1801/11971 - Tempo rimanente stimato: 246.68 secondi
# Elaborazione immagine 1901/11971 - Tempo rimanente stimato: 243.70 secondi
# Elaborazione immagine 2001/11971 - Tempo rimanente stimato: 240.87 secondi
# Elaborazione immagine 2101/11971 - Tempo rimanente stimato: 237.86 secondi
# Elaborazione immagine 2201/11971 - Tempo rimanente stimato: 235.14 secondi
# Elaborazione immagine 2301/11971 - Tempo rimanente stimato: 232.37 secondi
# Elaborazione immagine 2401/11971 - Tempo rimanente stimato: 229.62 secondi
# Elaborazione immagine 2501/11971 - Tempo rimanente stimato: 226.97 secondi
# Elaborazione immagine 2601/11971 - Tempo rimanente stimato: 224.30 secondi
# Elaborazione immagine 2701/11971 - Tempo rimanente stimato: 221.88 secondi
# Elaborazione immagine 2801/11971 - Tempo rimanente stimato: 219.41 secondi
# Elaborazione immagine 2901/11971 - Tempo rimanente stimato: 216.89 secondi
# Elaborazione immagine 3001/11971 - Tempo rimanente stimato: 214.14 secondi
# Elaborazione immagine 3101/11971 - Tempo rimanente stimato: 211.29 secondi
# Elaborazione immagine 3201/11971 - Tempo rimanente stimato: 211.62 secondi
# Elaborazione immagine 3301/11971 - Tempo rimanente stimato: 208.88 secondi
# Elaborazione immagine 3401/11971 - Tempo rimanente stimato: 206.17 secondi
# Elaborazione immagine 3501/11971 - Tempo rimanente stimato: 203.53 secondi
# Elaborazione immagine 3601/11971 - Tempo rimanente stimato: 201.11 secondi
# Elaborazione immagine 3701/11971 - Tempo rimanente stimato: 198.76 secondi
# Elaborazione immagine 3801/11971 - Tempo rimanente stimato: 196.24 secondi
# Elaborazione immagine 3901/11971 - Tempo rimanente stimato: 193.76 secondi
# Elaborazione immagine 4001/11971 - Tempo rimanente stimato: 191.69 secondi
# Elaborazione immagine 4101/11971 - Tempo rimanente stimato: 189.18 secondi
# Elaborazione immagine 4201/11971 - Tempo rimanente stimato: 186.64 secondi
# Elaborazione immagine 4301/11971 - Tempo rimanente stimato: 184.14 secondi
# Elaborazione immagine 4401/11971 - Tempo rimanente stimato: 181.58 secondi
# Elaborazione immagine 4501/11971 - Tempo rimanente stimato: 179.04 secondi
# Elaborazione immagine 4601/11971 - Tempo rimanente stimato: 176.47 secondi
# Elaborazione immagine 4701/11971 - Tempo rimanente stimato: 174.02 secondi
# Elaborazione immagine 4801/11971 - Tempo rimanente stimato: 171.37 secondi
# Elaborazione immagine 4901/11971 - Tempo rimanente stimato: 168.94 secondi
# Elaborazione immagine 5001/11971 - Tempo rimanente stimato: 166.48 secondi
# Elaborazione immagine 5101/11971 - Tempo rimanente stimato: 163.96 secondi
# Elaborazione immagine 5201/11971 - Tempo rimanente stimato: 161.60 secondi
# Elaborazione immagine 5301/11971 - Tempo rimanente stimato: 159.20 secondi
# Elaborazione immagine 5401/11971 - Tempo rimanente stimato: 156.80 secondi
# Elaborazione immagine 5501/11971 - Tempo rimanente stimato: 154.32 secondi
# Elaborazione immagine 5601/11971 - Tempo rimanente stimato: 151.95 secondi
# Elaborazione immagine 5701/11971 - Tempo rimanente stimato: 149.38 secondi
# Elaborazione immagine 5801/11971 - Tempo rimanente stimato: 146.83 secondi
# Elaborazione immagine 5901/11971 - Tempo rimanente stimato: 144.16 secondi
# Elaborazione immagine 6001/11971 - Tempo rimanente stimato: 141.44 secondi
# Elaborazione immagine 6101/11971 - Tempo rimanente stimato: 138.77 secondi
# Elaborazione immagine 6201/11971 - Tempo rimanente stimato: 136.05 secondi
# Elaborazione immagine 6301/11971 - Tempo rimanente stimato: 133.43 secondi
# Elaborazione immagine 6401/11971 - Tempo rimanente stimato: 131.04 secondi
# Elaborazione immagine 6501/11971 - Tempo rimanente stimato: 128.30 secondi
# Elaborazione immagine 6601/11971 - Tempo rimanente stimato: 125.56 secondi
# Elaborazione immagine 6701/11971 - Tempo rimanente stimato: 123.11 secondi
# Elaborazione immagine 6801/11971 - Tempo rimanente stimato: 120.58 secondi
# Elaborazione immagine 6901/11971 - Tempo rimanente stimato: 117.91 secondi
# Elaborazione immagine 7001/11971 - Tempo rimanente stimato: 115.28 secondi
# Elaborazione immagine 7101/11971 - Tempo rimanente stimato: 112.89 secondi
# Elaborazione immagine 7201/11971 - Tempo rimanente stimato: 110.33 secondi
# Elaborazione immagine 7301/11971 - Tempo rimanente stimato: 107.77 secondi
# Elaborazione immagine 7401/11971 - Tempo rimanente stimato: 105.20 secondi
# Elaborazione immagine 7501/11971 - Tempo rimanente stimato: 102.79 secondi
# Elaborazione immagine 7601/11971 - Tempo rimanente stimato: 100.32 secondi
# Elaborazione immagine 7701/11971 - Tempo rimanente stimato: 97.77 secondi
# Elaborazione immagine 7801/11971 - Tempo rimanente stimato: 95.35 secondi
# Elaborazione immagine 7901/11971 - Tempo rimanente stimato: 92.96 secondi
# Elaborazione immagine 8001/11971 - Tempo rimanente stimato: 90.52 secondi
# Elaborazione immagine 8101/11971 - Tempo rimanente stimato: 88.09 secondi
# Elaborazione immagine 8201/11971 - Tempo rimanente stimato: 85.62 secondi
# Elaborazione immagine 8301/11971 - Tempo rimanente stimato: 83.19 secondi
# Elaborazione immagine 8401/11971 - Tempo rimanente stimato: 80.71 secondi
# Elaborazione immagine 8501/11971 - Tempo rimanente stimato: 78.27 secondi
# Elaborazione immagine 8601/11971 - Tempo rimanente stimato: 75.82 secondi
# Elaborazione immagine 8701/11971 - Tempo rimanente stimato: 73.40 secondi
# Elaborazione immagine 8801/11971 - Tempo rimanente stimato: 70.98 secondi
# Elaborazione immagine 8901/11971 - Tempo rimanente stimato: 68.54 secondi
# Elaborazione immagine 9001/11971 - Tempo rimanente stimato: 66.24 secondi
# Elaborazione immagine 9101/11971 - Tempo rimanente stimato: 63.87 secondi
# Elaborazione immagine 9201/11971 - Tempo rimanente stimato: 61.52 secondi
# Elaborazione immagine 9301/11971 - Tempo rimanente stimato: 59.21 secondi
# Elaborazione immagine 9401/11971 - Tempo rimanente stimato: 56.89 secondi
# Elaborazione immagine 9501/11971 - Tempo rimanente stimato: 54.58 secondi
# Elaborazione immagine 9601/11971 - Tempo rimanente stimato: 52.29 secondi
# Elaborazione immagine 9701/11971 - Tempo rimanente stimato: 49.96 secondi
# Elaborazione immagine 9801/11971 - Tempo rimanente stimato: 47.69 secondi
# Elaborazione immagine 9901/11971 - Tempo rimanente stimato: 45.42 secondi
# Elaborazione immagine 10001/11971 - Tempo rimanente stimato: 43.16 secondi
# Elaborazione immagine 10101/11971 - Tempo rimanente stimato: 40.88 secondi
# Elaborazione immagine 10201/11971 - Tempo rimanente stimato: 38.66 secondi
# Elaborazione immagine 10301/11971 - Tempo rimanente stimato: 36.42 secondi
# Elaborazione immagine 10401/11971 - Tempo rimanente stimato: 34.20 secondi
# Elaborazione immagine 10501/11971 - Tempo rimanente stimato: 31.98 secondi
# Elaborazione immagine 10601/11971 - Tempo rimanente stimato: 29.75 secondi
# Elaborazione immagine 10701/11971 - Tempo rimanente stimato: 27.53 secondi
# Elaborazione immagine 10801/11971 - Tempo rimanente stimato: 25.33 secondi
# Elaborazione immagine 10901/11971 - Tempo rimanente stimato: 23.12 secondi
# Elaborazione immagine 11001/11971 - Tempo rimanente stimato: 20.91 secondi
# Elaborazione immagine 11101/11971 - Tempo rimanente stimato: 18.74 secondi
# Elaborazione immagine 11201/11971 - Tempo rimanente stimato: 16.56 secondi
# Elaborazione immagine 11301/11971 - Tempo rimanente stimato: 14.39 secondi
# Elaborazione immagine 11401/11971 - Tempo rimanente stimato: 12.23 secondi
# Elaborazione immagine 11501/11971 - Tempo rimanente stimato: 10.06 secondi
# Elaborazione immagine 11601/11971 - Tempo rimanente stimato: 7.91 secondi
# Elaborazione immagine 11701/11971 - Tempo rimanente stimato: 5.77 secondi
# Elaborazione immagine 11801/11971 - Tempo rimanente stimato: 3.64 secondi
# Elaborazione immagine 11901/11971 - Tempo rimanente stimato: 1.51 secondi
# Feature salvate in ../features\filtered_small_with_cleaned_retrieval_augmented_90_labels_resnet50_features_normalized.npz
# Caricamento delle feature da ../features\val_info_resnet50_features_normalized.npz
# Caricamento delle feature da ../features\features_test_degraded_normalized.npz

# %%
log_path = "results_log.csv"
log_columns = [
    "Dimension", "Model", "K", "Accuracy",  "Top-5 Accuracy",  "Top-10 Accuracy",  "Loss"
]
logs = []

# Combinazioni di dimensioni e feature
configurations = [
    {"dimension": 70, "features": features_70, "labels": [labels_70]},
    {"dimension": 80, "features": features_80, "labels": [labels_80]},
    {"dimension": 90, "features": features_90, "labels": [labels_90]}
]

def train_and_evaluate_neural_network_one_layer(X, y, X_test, y_test, X_test_degraded, y_test_degraded):
    one_layer_model = OneLayerNetwork(2048, 251)
    one_layer_optimizer = torch.optim.Adam(one_layer_model.parameters(), lr=0.01)
    one_layer_scheduler = torch.optim.lr_scheduler.StepLR(one_layer_optimizer, step_size=5, gamma=0.1)
    one_layer_model_option = ModelOptions(torch.nn.CrossEntropyLoss(), one_layer_optimizer, one_layer_scheduler, input_dim = 2048)
    nn = NeuralNetwork(one_layer_model, one_layer_model_option)
    
    # Split data seed 42
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
    
    # Convert to torch tensors and create datasets
    X_train_tensor = torch.FloatTensor(X_train)
    y_train_tensor = torch.LongTensor(y_train)
    X_val_tensor = torch.FloatTensor(X_val)
    y_val_tensor = torch.LongTensor(y_val)
    
    X_test_tensor = torch.FloatTensor(X_test)
    y_test_tensor = torch.LongTensor(y_test)
    X_test_degraded_tensor = torch.FloatTensor(X_test_degraded)
    y_test_degraded_tensor = torch.LongTensor(y_test_degraded)
    
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_degraded_dataset = TensorDataset(X_test_degraded_tensor, y_test_degraded_tensor)
    
    train_loader = DataLoader(train_dataset,  batch_size=one_layer_model_option.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_degraded_loader = DataLoader(test_degraded_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)

    nn.fit(train_loader, val_loader)
    loss, top1_accuracy, top5_accuracy, top10_accuracy, y_pred_top1, y_test = nn.predict(test_loader)
    loss_degraded, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, y_pred_top1_degraded, y_test_degraded = nn.predict(test_degraded_loader)
    
    return top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded


def train_and_evaluate_neural_network_classifer(X, y, X_test, y_test, X_test_degraded, y_test_degraded):
    one_layer_model = ClassifierNetwork(2048, 251)
    one_layer_optimizer = torch.optim.Adam(one_layer_model.parameters(), lr=0.01)
    one_layer_scheduler = torch.optim.lr_scheduler.StepLR(one_layer_optimizer, step_size=5, gamma=0.1)
    one_layer_model_option = ModelOptions(torch.nn.CrossEntropyLoss(), one_layer_optimizer, one_layer_scheduler, input_dim = 2048)
    nn = NeuralNetwork(one_layer_model, one_layer_model_option)
    
    # Split data seed 42
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
    
    # Convert to torch tensors and create datasets
    X_train_tensor = torch.FloatTensor(X_train)
    y_train_tensor = torch.LongTensor(y_train)
    X_val_tensor = torch.FloatTensor(X_val)
    y_val_tensor = torch.LongTensor(y_val)
    
    X_test_tensor = torch.FloatTensor(X_test)
    y_test_tensor = torch.LongTensor(y_test)
    X_test_degraded_tensor = torch.FloatTensor(X_test_degraded)
    y_test_degraded_tensor = torch.LongTensor(y_test_degraded)
    
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_degraded_dataset = TensorDataset(X_test_degraded_tensor, y_test_degraded_tensor)
    
    train_loader = DataLoader(train_dataset,  batch_size=one_layer_model_option.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_degraded_loader = DataLoader(test_degraded_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)

    nn.fit(train_loader, val_loader)
    loss, top1_accuracy, top5_accuracy, top10_accuracy, y_pred_top1, y_test = nn.predict(test_loader)
    loss_degraded, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, y_pred_top1_degraded, y_test_degraded = nn.predict(test_degraded_loader)
    
    return top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded


# Cross-validation 80-20 e test
for config in configurations:
    dim = config["dimension"]
    print(f"Iniziando configurazione per dimensione: {dim}")

    current_features = config["features"]
    current_labels = config["labels"][0]
    
    # Prova con diversi modelli
    print("  Prova con modello One Layer")  
    top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_one_layer(current_features, current_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
    print(f"    Test Set One Layer: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
    print(f"    Test Set Degraded One Layer: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
    logs.append([dim, "Test Set One Layer", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
    logs.append([dim, "Test Set Degraded One Layer", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded]) 
    
    print("  Prova con modello Classifier")
    top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_classifer(current_features, current_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
    print(f"    Test Set Classifier: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
    print(f"    Test Set Degraded Classifier: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
    logs.append([dim, "Test Set Classifier", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
    logs.append([dim, "Test Set Degraded Classifier", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded])
            
    # Prova con diversi valori di K
    for k in [5, 10, 25, 50, 100, 150]:
        print(f"    Valutazione per K={k}")

        # Validation set solo con feature della dimensione specifica
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(current_features, current_labels)

        # Test su test set
        top_5_predictions_test = np.argsort(knn.predict_proba(features_test), axis=1)[:, -5:]
        top_10_predictions_test = np.argsort(knn.predict_proba(features_test), axis=1)[:, -10:]
        acc_test = knn.score(features_test, labels_test)
        top_5_acc_test = np.mean([y in top_5 for y, top_5 in zip(labels_test, top_5_predictions_test)])
        top_10_acc_test = np.mean([y in top_10 for y, top_10 in zip(labels_test, top_10_predictions_test)])
        logs.append([dim, "Test Set KNN", k, acc_test, top_5_acc_test, top_10_acc_test])
        print(f"      Test Set KNN: Accuracy={acc_test}, Top-5 Accuracy={top_5_acc_test}, Top-10 Accuracy={top_10_acc_test}")

        # Test su test set degraded
        top_5_predictions_test_degraded = np.argsort(knn.predict_proba(features_test_degraded), axis=1)[:, -5:]
        top_10_predictions_test_degraded = np.argsort(knn.predict_proba(features_test_degraded), axis=1)[:, -10:]
        acc_test_degraded = knn.score(features_test_degraded, labels_test_degraded)
        top_5_acc_test_degraded = np.mean([y in top_5 for y, top_5 in zip(labels_test_degraded, top_5_predictions_test_degraded)])
        top_10_acc_test_degraded = np.mean([y in top_10 for y, top_10 in zip(labels_test_degraded, top_10_predictions_test_degraded)])
        logs.append([dim, "Test Set Degraded KNN", k, acc_test_degraded, top_5_acc_test_degraded, top_10_acc_test_degraded])
        print(f"      Test Set Degraded KNN: Accuracy={acc_test_degraded}, Top-5 Accuracy={top_5_acc_test_degraded}, Top-10 Accuracy={top_10_acc_test_degraded}")
                
# Salva i log in un CSV
log_df = pd.DataFrame(logs, columns=log_columns)
log_df.to_csv(log_path, index=False)
print(f"Log salvato in {log_path}")
# Out:
# Iniziando configurazione per dimensione: 70
#   Prova con modello One Layer
# Epoch 1/100:
#   Train Loss: 5.5761, Train Accuracy: 0.68%
#   Val Loss: 5.5257, Val Accuracy: 0.85%
# Epoch 2/100:
#   Train Loss: 5.1394, Train Accuracy: 1.55%
#   Val Loss: 5.3330, Val Accuracy: 1.94%
# Epoch 3/100:
#   Train Loss: 4.8743, Train Accuracy: 2.43%
#   Val Loss: 4.9118, Val Accuracy: 1.99%
# Epoch 4/100:
#   Train Loss: 4.6991, Train Accuracy: 3.47%
#   Val Loss: 4.7044, Val Accuracy: 3.02%
# Epoch 5/100:
#   Train Loss: 4.5404, Train Accuracy: 4.85%
#   Val Loss: 4.5421, Val Accuracy: 5.01%
# Epoch 6/100:
#   Train Loss: 4.4167, Train Accuracy: 5.81%
#   Val Loss: 4.3624, Val Accuracy: 5.98%
# Epoch 7/100:
#   Train Loss: 4.3839, Train Accuracy: 6.18%
#   Val Loss: 4.3165, Val Accuracy: 6.78%
# Epoch 8/100:
#   Train Loss: 4.3605, Train Accuracy: 6.46%
#   Val Loss: 4.2818, Val Accuracy: 7.57%
# Epoch 9/100:
#   Train Loss: 4.3327, Train Accuracy: 7.06%
#   Val Loss: 4.2559, Val Accuracy: 8.20%
# Epoch 10/100:
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 13/100:
#   Train Loss: 1.3489, Train Accuracy: 63.24%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 14/100:
#   Train Loss: 1.3555, Train Accuracy: 62.71%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 15/100:
#   Train Loss: 1.3515, Train Accuracy: 62.85%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 16/100:
#   Train Loss: 1.3281, Train Accuracy: 62.87%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 17/100:
#   Train Loss: 1.3548, Train Accuracy: 63.04%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 18/100:
#   Train Loss: 1.3526, Train Accuracy: 62.89%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
# Epoch 19/100:
#   Train Loss: 1.3439, Train Accuracy: 63.32%
#   Val Loss: 2.7883, Val Accuracy: 34.56%
#
# Early stopping triggered. Stopping training.
#     Test Set Classifier: Accuracy=0.26796731699182924, Top-5 Accuracy=0.5280973820243455, Top-10 Accuracy=0.6523261630815408, Loss=3.501141587893168
#     Test Set Degraded Classifier: Accuracy=0.19001167250291812, Top-5 Accuracy=0.4041187260296815, Top-10 Accuracy=0.5168417542104385, Loss=4.345327218373616
#     Valutazione per K=5
#       Test Set KNN: Accuracy=0.1911789227947307, Top-5 Accuracy=0.3868600967150242, Top-10 Accuracy=0.40028347507086876
#       Test Set Degraded KNN: Accuracy=0.13239953309988328, Top-5 Accuracy=0.2809738202434551, Top-10 Accuracy=0.29681507420376857
#     Valutazione per K=10
#       Test Set KNN: Accuracy=0.21302317825579456, Top-5 Accuracy=0.4030348507587127, Top-10 Accuracy=0.4916624979156245
#       Test Set Degraded KNN: Accuracy=0.14849091212272802, Top-5 Accuracy=0.2933966983491746, Top-10 Accuracy=0.3734367183591796
#     Valutazione per K=25
#       Test Set KNN: Accuracy=0.22719693179923295, Top-5 Accuracy=0.439719859929965, Top-10 Accuracy=0.5281807570451893
#       Test Set Degraded KNN: Accuracy=0.1606636651659163, Top-5 Accuracy=0.32291145572786395, Top-10 Accuracy=0.4019509754877439
#     Valutazione per K=50
#       Test Set KNN: Accuracy=0.23161580790395198, Top-5 Accuracy=0.4593129898282475, Top-10 Accuracy=0.5636151409037852
#       Test Set Degraded KNN: Accuracy=0.16283141570785392, Top-5 Accuracy=0.34067033516758377, Top-10 Accuracy=0.42779723194930797
#     Valutazione per K=100
#       Test Set KNN: Accuracy=0.23411705852926462, Top-5 Accuracy=0.47798899449724863, Top-10 Accuracy=0.5867933966983492
#       Test Set Degraded KNN: Accuracy=0.16574954143738535, Top-5 Accuracy=0.3585125896281474, Top-10 Accuracy=0.4510588627647157
#     Valutazione per K=150
#       Test Set KNN: Accuracy=0.23069868267467067, Top-5 Accuracy=0.4853259963314991, Top-10 Accuracy=0.5993830248457562
#       Test Set Degraded KNN: Accuracy=0.16741704185426046, Top-5 Accuracy=0.3645989661497415, Top-10 Accuracy=0.4610638652659663
# Log salvato in results_log.csv
