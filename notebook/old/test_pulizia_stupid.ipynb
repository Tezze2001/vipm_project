# %%
import os
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import pytesseract
import shutil
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

class ImageDatasetCleaner:
    def __init__(self, csv_path, image_folder, output_folder):
        """
        Inizializza il cleaner con il file CSV, la cartella delle immagini e la cartella di output
        """
        self.df = pd.read_csv(csv_path, header=None, names=["Image", "Label"])
        self.image_folder = image_folder
        self.output_folder = output_folder
        self.bad_images_folder = os.path.join(output_folder, "rejected")
        self.clean_images_folder = os.path.join(output_folder, "clean")
        
        # Crea le cartelle di output se non esistono
        for folder in [self.output_folder, self.bad_images_folder, self.clean_images_folder]:
            if not os.path.exists(folder):
                os.makedirs(folder)
        
        # Carica il modello face detection
        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        
        # Crea un nuovo DataFrame per tenere traccia dei risultati
        self.results_df = self.df.copy()
        self.results_df['Status'] = 'clean'
        self.results_df['Rejection_Reason'] = ''

    def has_text(self, image_path, text_threshold=10):
        """
        Rileva la presenza di testo nell'immagine usando pytesseract
        """
        try:
            image = Image.open(image_path)
            text = pytesseract.image_to_string(image)
            # Conta il numero di caratteri alfanumerici
            char_count = sum(c.isalnum() for c in text)
            return char_count > text_threshold
        except Exception as e:
            print(f"Errore nel rilevamento del testo per {image_path}: {str(e)}")
            return False

    def has_faces(self, image_path, min_face_size=0.1, scale_factor=1.2, min_neighbors=8):
        """
        Rileva la presenza di volti nell'immagine con parametri ottimizzati
        per ridurre i falsi positivi
        
        Parameters:
        - min_face_size: dimensione minima del volto rispetto all'immagine (0.1 = 10% dell'immagine)
        - scale_factor: fattore di scala per la detection (più alto = più veloce ma meno preciso)
        - min_neighbors: numero minimo di detection vicine per considerare un volto (più alto = meno falsi positivi)
        """
        try:
            image = cv2.imread(image_path)
            if image is None:
                return False
                
            height, width = image.shape[:2]
            min_size = int(min(height, width) * min_face_size)
            
            # Converti in scala di grigi
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            
            # Equalizza l'istogramma per migliorare il contrasto
            gray = cv2.equalizeHist(gray)
            
            # Rileva volti frontali
            faces_front = self.face_cascade.detectMultiScale(
                gray,
                scaleFactor=scale_factor,
                minNeighbors=min_neighbors,
                minSize=(min_size, min_size)
            )
        
            
            # Verifica la presenza di volti di dimensione significativa
            all_faces = list(faces_front)
            
            for (x, y, w, h) in all_faces:
                # Calcola l'area relativa del volto rispetto all'immagine
                face_area = w * h
                image_area = height * width
                face_ratio = face_area / image_area
                
                # Se troviamo almeno un volto di dimensione significativa, restituisci True
                if face_ratio > min_face_size * min_face_size:
                    return True
            
            return False
            
        except Exception as e:
            print(f"Errore nel rilevamento dei volti per {image_path}: {str(e)}")
            return False
        
        
    def is_cartoon(self, image_path):
        """
        Riconosce se un'immagine ha caratteristiche di un cartone animato.
        
        Args:
            image_path (str): Percorso dell'immagine da analizzare.
        
        Returns:
            bool: True se l'immagine è un cartone, False altrimenti.
        """
        try:
            # Carica l'immagine
            image = cv2.imread(image_path)
            if image is None:
                print(f"Impossibile caricare l'immagine: {image_path}")
                return False
            
            # Converti l'immagine in scala di grigi
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            
            # Rileva i bordi con l'algoritmo di Canny
            edges = cv2.Canny(gray, threshold1=100, threshold2=200)
            
            # Conta i contorni
            contours, _ = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
            contour_count = len(contours)
            
            # Calcola la saturazione media
            hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            saturation = hsv[:, :, 1]  # Canale della saturazione
            avg_saturation = np.mean(saturation)
            
            # Calcola la deviazione standard dei colori
            color_std = np.std(image)
        
            # Heuristica per determinare se è un cartone:
            # - Molti contorni (indicando bordi definiti)
            # - Alta saturazione media (indicando colori vividi)
            # - Bassa deviazione standard dei colori (indicando colori piatti)
            is_cartoon = contour_count > 1000 and avg_saturation > 50 and color_std < 70
            
            return is_cartoon
    
        except Exception as e:
            print(f"Errore nel rilevamento cartoon per {image_path}: {str(e)}")
            return False


    def clean_dataset(self):
        """
        Pulisce il dataset spostando le immagini nelle appropriate cartelle e aggiorna il CSV
        """
        total_images = len(self.df)
        rejected_images = 0
        
        for idx, row in self.df.iterrows():
            image_path = os.path.join(self.image_folder, row['Image'])
            
            if not os.path.exists(image_path):
                print(f"Immagine non trovata: {image_path}")
                continue
            
            should_reject = False
            reasons = []
            
            # Controlla testo
            # if self.has_text(image_path):
            #     should_reject = True
            #     reasons.append("testo")
            
            # # # Controlla volti
            # if self.has_faces(image_path):
            #     should_reject = True
            #     reasons.append("volti")
            
            # Controlla se è un cartone
            if self.is_cartoon(image_path):
                should_reject = True
                reasons.append("cartone animato")
            
            # Aggiorna il DataFrame dei risultati
            if should_reject:
                rejected_images += 1
                self.results_df.at[idx, 'Status'] = 'rejected'
                self.results_df.at[idx, 'Rejection_Reason'] = ', '.join(reasons)
                dest_path = os.path.join(self.bad_images_folder, row['Image'])
                print(f"Rifiutato {row['Image']} per: {', '.join(reasons)}")
            else:
                dest_path = os.path.join(self.clean_images_folder, row['Image'])
            
            # Copia l'immagine nella cartella appropriata
            shutil.copy2(image_path, dest_path)
        
        # Salva il DataFrame aggiornato
        self.results_df.to_csv(os.path.join(self.output_folder, 'cleaned_dataset.csv'), index=False)
        
        return total_images, rejected_images

def main():
    # Esempio di utilizzo con la struttura del dataset fornita
    csv_path = 'dataset/train_small.csv'
    image_folder = 'dataset/train_set'
    output_folder = 'dataset/cleaned_output'
    
    cleaner = ImageDatasetCleaner(csv_path, image_folder, output_folder)
    total, rejected = cleaner.clean_dataset()
    
    print(f"\nRisultati pulizia dataset:")
    print(f"Totale immagini processate: {total}")
    print(f"Immagini rifiutate: {rejected}")
    print(f"Percentuale rifiutate: {(rejected/total)*100:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Rifiutato train_067490.jpg per: cartone animato
# Rifiutato train_074552.jpg per: cartone animato
# Rifiutato train_032804.jpg per: cartone animato
# Rifiutato train_018005.jpg per: cartone animato
# Rifiutato train_026961.jpg per: cartone animato
# Rifiutato train_094889.jpg per: cartone animato
# Rifiutato train_031690.jpg per: cartone animato
# Rifiutato train_031699.jpg per: cartone animato
# Rifiutato train_098586.jpg per: cartone animato
# Rifiutato train_016284.jpg per: cartone animato
# Rifiutato train_062919.jpg per: cartone animato
# Rifiutato train_032351.jpg per: cartone animato
# Rifiutato train_007933.jpg per: cartone animato
# Rifiutato train_081767.jpg per: cartone animato
# Rifiutato train_082015.jpg per: cartone animato
# Rifiutato train_036198.jpg per: cartone animato
# Rifiutato train_020751.jpg per: cartone animato
# Rifiutato train_038184.jpg per: cartone animato
# Rifiutato train_013142.jpg per: cartone animato
# Rifiutato train_013336.jpg per: cartone animato
# Rifiutato train_063942.jpg per: cartone animato
# Rifiutato train_034273.jpg per: cartone animato
# Rifiutato train_034325.jpg per: cartone animato
# Rifiutato train_034416.jpg per: cartone animato
# Rifiutato train_040991.jpg per: cartone animato
# Rifiutato train_087735.jpg per: cartone animato
# Rifiutato train_087772.jpg per: cartone animato
# Rifiutato train_023552.jpg per: cartone animato
# Rifiutato train_057231.jpg per: cartone animato
# Rifiutato train_095657.jpg per: cartone animato
# Rifiutato train_001083.jpg per: cartone animato
# Rifiutato train_000052.jpg per: cartone animato
# Rifiutato train_034538.jpg per: cartone animato
# Rifiutato train_047029.jpg per: cartone animato
# Rifiutato train_001774.jpg per: cartone animato
# Rifiutato train_002128.jpg per: cartone animato
# Rifiutato train_011050.jpg per: cartone animato
# Rifiutato train_039836.jpg per: cartone animato
# Rifiutato train_039899.jpg per: cartone animato
# Rifiutato train_039906.jpg per: cartone animato
# Rifiutato train_059137.jpg per: cartone animato
# Rifiutato train_061512.jpg per: cartone animato
# Rifiutato train_061877.jpg per: cartone animato
# Rifiutato train_063249.jpg per: cartone animato
# Rifiutato train_076501.jpg per: cartone animato
# Rifiutato train_038851.jpg per: cartone animato
# Rifiutato train_015034.jpg per: cartone animato
# Rifiutato train_081590.jpg per: cartone animato
# Rifiutato train_093096.jpg per: cartone animato
# Rifiutato train_093178.jpg per: cartone animato
# Rifiutato train_093180.jpg per: cartone animato
# Rifiutato train_077977.jpg per: cartone animato
# Rifiutato train_080494.jpg per: cartone animato
# Rifiutato train_083023.jpg per: cartone animato
# Rifiutato train_083207.jpg per: cartone animato
# Rifiutato train_030099.jpg per: cartone animato
# Rifiutato train_067836.jpg per: cartone animato
# Rifiutato train_067862.jpg per: cartone animato
# Rifiutato train_068037.jpg per: cartone animato
# Rifiutato train_062048.jpg per: cartone animato
# Rifiutato train_050039.jpg per: cartone animato
# Rifiutato train_054094.jpg per: cartone animato
# Rifiutato train_054141.jpg per: cartone animato
# Rifiutato train_016753.jpg per: cartone animato
# Rifiutato train_017010.jpg per: cartone animato
# Rifiutato train_044232.jpg per: cartone animato
# Rifiutato train_044244.jpg per: cartone animato
# Rifiutato train_084044.jpg per: cartone animato
# Rifiutato train_046904.jpg per: cartone animato
# Rifiutato train_039683.jpg per: cartone animato
# Rifiutato train_072823.jpg per: cartone animato
# Rifiutato train_025962.jpg per: cartone animato
# Rifiutato train_026161.jpg per: cartone animato
# Rifiutato train_066250.jpg per: cartone animato
# Rifiutato train_045688.jpg per: cartone animato
# Rifiutato train_040589.jpg per: cartone animato
# Rifiutato train_060833.jpg per: cartone animato
# Rifiutato train_079393.jpg per: cartone animato
# Rifiutato train_073273.jpg per: cartone animato
# Rifiutato train_073436.jpg per: cartone animato
# Rifiutato train_097271.jpg per: cartone animato
# Rifiutato train_035063.jpg per: cartone animato
# Rifiutato train_035355.jpg per: cartone animato
# Rifiutato train_043615.jpg per: cartone animato
# Rifiutato train_014589.jpg per: cartone animato
# Rifiutato train_005350.jpg per: cartone animato
# Rifiutato train_065863.jpg per: cartone animato
# Rifiutato train_091208.jpg per: cartone animato
# Rifiutato train_091338.jpg per: cartone animato
# Rifiutato train_091449.jpg per: cartone animato
# Rifiutato train_083572.jpg per: cartone animato
# Rifiutato train_043111.jpg per: cartone animato
# Rifiutato train_103902.jpg per: cartone animato
# Rifiutato train_104607.jpg per: cartone animato
# Rifiutato train_106545.jpg per: cartone animato
# Rifiutato train_107000.jpg per: cartone animato
# Rifiutato train_107241.jpg per: cartone animato
# Rifiutato train_109022.jpg per: cartone animato
# Rifiutato train_110080.jpg per: cartone animato
# Rifiutato train_113552.jpg per: cartone animato
# Rifiutato train_113684.jpg per: cartone animato
# Rifiutato train_113970.jpg per: cartone animato
# Rifiutato train_115415.jpg per: cartone animato
# Rifiutato train_115450.jpg per: cartone animato
# Rifiutato train_115848.jpg per: cartone animato
# Rifiutato train_118683.jpg per: cartone animato
# Rifiutato train_118778.jpg per: cartone animato
#
# Risultati pulizia dataset:
# Totale immagini processate: 5020
# Immagini rifiutate: 107
# Percentuale rifiutate: 2.13%

# %%
import pandas as pd
import numpy as np
import cv2
import os
from skimage.feature import local_binary_pattern
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.covariance import EllipticEnvelope

class ImageDatasetCleaner:
    def __init__(self, csv_path, image_folder, output_folder):
        """
        Inizializza il cleaner con il file CSV, la cartella delle immagini e la cartella di output
        """
        self.df = pd.read_csv(csv_path, header=None, names=["Image", "Label"])
        self.image_folder = image_folder
        self.output_folder = output_folder
        self.bad_images_folder = os.path.join(output_folder, "rejected")
        self.clean_images_folder = os.path.join(output_folder, "clean")
        
        # Crea le cartelle di output se non esistono
        for folder in [self.output_folder, self.bad_images_folder, self.clean_images_folder]:
            if not os.path.exists(folder):
                os.makedirs(folder)
        
        # Carica il modello face detection
        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        
        # Crea un nuovo DataFrame per tenere traccia dei risultati
        self.results_df = self.df.copy()
        self.results_df['Status'] = 'clean'
        self.results_df['Rejection_Reason'] = ''
        
        # Parametri LBP
        self.n_points = 24
        self.radius = 8
        self.target_size = (256, 256)  # Dimensione standard per tutte le immagini
        
    def extract_lbp_features(self, image_path):
        """
        Estrae le feature LBP da un'immagine
        """
        try:
            # Carica e ridimensiona l'immagine
            img = cv2.imread(image_path)
            if img is None:
                return None
                
            img = cv2.resize(img, self.target_size)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            
            # Calcola LBP
            lbp = local_binary_pattern(gray, self.n_points, self.radius, method='uniform')
            
            # Calcola l'istogramma delle feature LBP
            n_bins = self.n_points + 2
            hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins), density=True)
            
            return hist
            
        except Exception as e:
            print(f"Errore nell'elaborazione di {image_path}: {str(e)}")
            return None
            
    def detect_outliers(self, contamination=0.1):
        """
        Rileva gli outlier usando le feature LBP
        """
        print("Estraendo le feature LBP...")
        
        # Estrai le feature per tutte le immagini
        features_list = []
        valid_indices = []
        
        for idx, row in self.df.iterrows():
            image_path = os.path.join(self.image_folder, row['Image'])
            features = self.extract_lbp_features(image_path)
            
            if features is not None:
                features_list.append(features)
                valid_indices.append(idx)
        
        if not features_list:
            raise ValueError("Nessuna feature valida estratta dalle immagini")
            
        # Converti in array numpy
        X = np.array(features_list)
        
        # Standardizza le feature
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # Applica PCA per ridurre la dimensionalità (opzionale ma consigliato)
        pca = PCA(n_components=0.95)  # Mantiene il 95% della varianza
        X_pca = pca.fit_transform(X_scaled)
        
        # Usa Elliptic Envelope per il rilevamento degli outlier
        outlier_detector = EllipticEnvelope(contamination=contamination, random_state=42)
        labels = outlier_detector.fit_predict(X_pca)
        
        # Aggiorna il DataFrame dei risultati
        for idx, label in zip(valid_indices, labels):
            if label == -1:  # outlier
                self.results_df.at[idx, 'Status'] = 'rejected'
                self.results_df.at[idx, 'Rejection_Reason'] = 'LBP outlier'
                
        # Calcola e stampa le statistiche
        n_outliers = sum(labels == -1)
        print(f"Trovati {n_outliers} outlier su {len(labels)} immagini totali")
        
    def process_dataset(self, contamination=0.1):
        """
        Elabora l'intero dataset applicando il rilevamento degli outlier
        """
        # Rileva gli outlier
        self.detect_outliers(contamination)
        
        # Sposta le immagini nelle cartelle appropriate
        for idx, row in self.results_df.iterrows():
            src_path = os.path.join(self.image_folder, row['Image'])
            
            if row['Status'] == 'rejected':
                dst_path = os.path.join(self.bad_images_folder, row['Image'])
            else:
                dst_path = os.path.join(self.clean_images_folder, row['Image'])
                
            try:
                # Copia l'immagine nella cartella appropriata
                import shutil
                shutil.copy2(src_path, dst_path)
            except Exception as e:
                print(f"Errore nel copiare {src_path}: {str(e)}")
        
        # Salva i risultati in un nuovo CSV
        results_path = os.path.join(self.output_folder, 'cleaning_results.csv')
        self.results_df.to_csv(results_path, index=False)
        
        print(f"Elaborazione completata. Risultati salvati in {results_path}")

# %%
cleaner = ImageDatasetCleaner('dataset/train_small.csv', 'dataset/train_set', 'output_folder')
cleaner.process_dataset(contamination=0.1)  # contamination è la percentuale attesa di outlier
# Out:
# Estraendo le feature LBP...
# Trovati 502 outlier su 5020 immagini totali
# Errore nel copiare dataset/train_set\train_059371.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059389.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059425.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059445.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059516.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059538.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059541.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059570.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059713.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059719.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059744.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059789.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059795.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059837.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059855.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059893.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059917.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059919.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059921.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_059928.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089398.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089407.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089435.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089456.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089510.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089516.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089530.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089579.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089594.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089613.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089629.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089681.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089700.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089720.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089739.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089740.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089773.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089783.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089842.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089844.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062381.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062412.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062446.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062491.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062493.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062510.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062538.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062569.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062571.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062577.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062627.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062644.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062652.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062665.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062667.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062682.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062692.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062702.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062726.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_062756.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067031.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067064.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067069.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067088.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067103.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067108.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067157.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067170.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067242.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067288.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067323.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067335.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067353.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067421.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067490.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067499.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067554.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067559.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_067565.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040012.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040039.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040054.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040070.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040078.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040187.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040198.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040203.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040219.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040231.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040248.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040257.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040266.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040305.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040326.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040410.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040424.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040434.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_040438.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074191.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074203.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074207.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074223.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074230.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074241.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074242.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074273.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074328.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074351.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074373.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074375.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074397.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074418.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074426.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074470.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074475.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074481.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074552.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_074584.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069104.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069121.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069123.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069151.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069161.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069171.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069207.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069215.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069224.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069247.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069296.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069308.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069313.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069336.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069347.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069358.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069382.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069404.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069430.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069500.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024255.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024264.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024272.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024314.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024332.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024360.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024381.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024389.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024402.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024424.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024453.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024471.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024538.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024553.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024565.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024595.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024608.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024611.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024629.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_024635.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085321.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085323.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085377.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085511.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085554.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085566.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085585.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085614.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085661.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085693.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085723.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085726.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085757.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085785.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085787.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085820.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085823.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085828.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085843.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085845.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008697.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008719.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008790.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008830.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008838.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008865.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008867.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008887.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008942.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_008944.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009027.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009039.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009045.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009067.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009120.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009132.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009140.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009143.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009148.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_009153.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006793.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006794.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006795.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006807.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006827.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006834.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006842.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006864.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006873.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006890.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006891.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006925.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007004.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007016.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007052.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007090.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007094.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007105.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007120.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_007130.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075674.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075683.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075723.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075772.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075822.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075832.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075839.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075842.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075944.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075945.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075980.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075981.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_075994.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076016.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076024.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076073.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076089.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076147.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_076154.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032521.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032603.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032624.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032626.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032628.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032687.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032736.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032748.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032761.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032767.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032804.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032830.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032832.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032863.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032902.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032924.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032940.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032955.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_032967.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_033128.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026411.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026416.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026420.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026428.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026434.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026455.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026457.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026478.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026491.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026507.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026538.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026557.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026559.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026563.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026564.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026579.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026655.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026686.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026714.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_026722.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006384.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006385.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006420.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006426.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006465.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006514.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006541.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006544.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006546.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006553.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006557.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006568.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006610.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006622.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006641.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006675.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006720.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006734.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006751.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_006774.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069559.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069562.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069579.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069610.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069614.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069633.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069651.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069654.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069671.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069690.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069691.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069704.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069714.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069721.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069731.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069776.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069799.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069812.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069821.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_069847.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017653.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017698.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017713.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017719.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017776.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017828.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017846.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017847.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017862.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017941.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017959.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_017994.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018005.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018024.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018025.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018049.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018071.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018111.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018126.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_018130.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022920.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022928.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022941.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022949.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022956.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_022972.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023036.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023044.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023050.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023076.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023095.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023102.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023141.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023152.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023206.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023234.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023249.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023314.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023318.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_023344.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054633.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054646.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054674.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054684.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054698.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054713.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054723.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054732.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054739.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054755.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054799.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054803.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054809.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054816.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054876.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054970.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_054989.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_055005.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_055124.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_055151.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089890.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089899.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089914.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089919.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089933.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089959.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089969.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_089985.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090034.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090110.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090157.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090168.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090170.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090184.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090207.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090233.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090266.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090295.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090340.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_090363.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084813.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084838.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084860.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084869.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084873.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084910.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084920.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084938.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084941.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_084946.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085035.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085068.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085129.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085151.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085168.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085171.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085191.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085245.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_085272.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_097940.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_097956.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_097977.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098004.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098062.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098090.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098114.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098137.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098176.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098206.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098208.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098256.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098268.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_098287.jpg: [WinError 3] The system cannot find the path specified
# ...
# Errore nel copiare dataset/train_set\train_117884.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_117894.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_117907.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_117927.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_117955.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118054.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118094.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118137.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118153.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118188.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118232.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118242.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118243.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118274.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118333.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118343.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118351.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118358.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118380.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118400.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118403.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118457.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118476.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118527.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118542.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118546.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118553.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118562.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118621.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118645.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118668.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118672.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118683.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118685.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118730.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118772.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118778.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118784.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118833.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118850.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118888.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118900.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118915.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118919.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118928.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118934.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118948.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118950.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_118994.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119000.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119075.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119089.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119106.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119114.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119154.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119170.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119173.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119208.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119214.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119215.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119222.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119233.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119247.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119259.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119264.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119392.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119397.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119421.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119431.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119466.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119472.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119474.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119489.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119507.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119516.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119522.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119620.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119628.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119650.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119661.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119673.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119693.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119696.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119792.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119814.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119819.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119838.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119880.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119891.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119927.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119945.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_119975.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120062.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120064.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120086.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120098.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120106.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120108.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120127.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120146.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120161.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120200.jpg: [WinError 3] The system cannot find the path specified
# Errore nel copiare dataset/train_set\train_120211.jpg: [WinError 3] The system cannot find the path specified
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 2
#       1 cleaner = ImageDatasetCleaner('dataset/train_small.csv', 'dataset/train_set', 'output_folder')
# ----> 2 cleaner.process_dataset(contamination=0.1)  # contamination è la percentuale attesa di outlier
#
# Cell In[21], line 136, in ImageDatasetCleaner.process_dataset(self, contamination)
#     134 # Salva i risultati in un nuovo CSV
#     135 results_path = os.path.join(self.output_folder, 'cleaning_results.csv')
# --> 136 self.results_df.to_csv(results_path, index=False)
#     138 print(f"Elaborazione completata. Risultati salvati in {results_path}")
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_folder'

# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from torchvision import transforms, models
from PIL import Image
import torch

class ImageDatasetCleaner:
    def __init__(self, csv_path, image_folder, output_folder):
        """
        Inizializza il cleaner con il file CSV, la cartella delle immagini e la cartella di output.
        """
        self.df = pd.read_csv(csv_path, header=None, names=["Image", "Label"])
        self.image_folder = image_folder
        self.output_folder = output_folder
        self.bad_images_folder = os.path.join(output_folder, "rejected")
        self.clean_images_folder = os.path.join(output_folder, "clean")

        # Crea le cartelle di output se non esistono
        for folder in [self.output_folder, self.bad_images_folder, self.clean_images_folder]:
            if not os.path.exists(folder):
                os.makedirs(folder)

        # Modello pre-addestrato
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = models.resnet18(pretrained=True)
        self.model = torch.nn.Sequential(*(list(self.model.children())[:-1]))
        self.model.to(self.device)
        self.model.eval()

    def extract_features(self, image_path):
        """
        Estrae i feature embeddings per un'immagine.
        """
        transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])
        image = Image.open(image_path).convert("RGB")
        image_tensor = transform(image).unsqueeze(0).to(self.device)

        with torch.no_grad():
            features = self.model(image_tensor).squeeze().cpu().numpy()
        return features

    def find_outliers(self):
        """
        Identifica le immagini outlier basandosi sui feature embeddings.
        """
        feature_list = []
        image_paths = []

        # Estrai feature per ogni immagine
        for _, row in self.df.iterrows():
            image_name = row["Image"]
            image_path = os.path.join(self.image_folder, image_name)

            if os.path.exists(image_path):
                try:
                    features = self.extract_features(image_path)
                    feature_list.append(features)
                    image_paths.append(image_name)
                except Exception as e:
                    print(f"Errore nell'elaborare l'immagine {image_name}: {e}")
                    continue

        # Converte in array per analisi
        feature_array = np.array(feature_list)

        # Modello per rilevare outlier
        clf = IsolationForest(contamination=0.05, random_state=42)
        outlier_pred = clf.fit_predict(feature_array)

        # Salva risultati
        self.df["Outlier"] = [1 if pred == -1 else 0 for pred in outlier_pred]
        self.df.to_csv(os.path.join(self.output_folder, "results.csv"), index=False)

        # Sposta le immagini nelle cartelle corrette
        for image_name, is_outlier in zip(image_paths, self.df["Outlier"]):
            src = os.path.join(self.image_folder, image_name)
            dest_folder = self.bad_images_folder if is_outlier else self.clean_images_folder
            dest = os.path.join(dest_folder, image_name)

            os.rename(src, dest)

        print("Pulizia completata. Risultati salvati in:", self.output_folder)

# %%
# Sostituisci i percorsi con i tuoi
cleaner = ImageDatasetCleaner('dataset/train_small.csv', 'dataset/train_set', 'output_folder3')
cleaner.find_outliers()
# Out:
# c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Sostituisci i percorsi con i tuoi
#       2 cleaner = ImageDatasetCleaner('dataset/train_small.csv', 'dataset/train_set', 'output_folder3')
# ----> 3 cleaner.find_outliers()
#
# Cell In[7], line 75, in ImageDatasetCleaner.find_outliers(self)
#      73 # Modello per rilevare outlier
#      74 clf = IsolationForest(contamination=0.05, random_state=42)
# ---> 75 outlier_pred = clf.fit_predict(feature_array)
#      77 # Salva risultati
#      78 self.df["Outlier"] = [1 if pred == -1 else 0 for pred in outlier_pred]
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\sklearn\base.py:1146, in OutlierMixin.fit_predict(self, X, y, **kwargs)
#    1132         warnings.warn(
#    1133             (
#    1134                 f"This object ({self.__class__.__name__}) has a `predict` "
#    (...)
#    1142             UserWarning,
#    1143         )
#    1145 # override for transductive outlier detectors like LocalOulierFactor
# -> 1146 return self.fit(X, **kwargs).predict(X)
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\sklearn\ensemble\_iforest.py:319, in IsolationForest.fit(self, X, y, sample_weight)
#     296 @_fit_context(prefer_skip_nested_validation=True)
#     297 def fit(self, X, y=None, sample_weight=None):
#     298     """
#     299     Fit estimator.
#     300
#    (...)
#     317         Fitted estimator.
#     318     """
# --> 319     X = validate_data(
#     320         self, X, accept_sparse=["csc"], dtype=tree_dtype, ensure_all_finite=False
#     321     )
#     322     if issparse(X):
#     323         # Pre-sort indices to avoid that each individual tree of the
#     324         # ensemble sorts the indices.
#     325         X.sort_indices()
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\sklearn\utils\validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File c:\Users\sguid\Uni\visual\project\venv\Lib\site-packages\sklearn\utils\validation.py:1093, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1086         else:
#    1087             msg = (
#    1088                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1089                 "Reshape your data either using array.reshape(-1, 1) if "
#    1090                 "your data has a single feature or array.reshape(1, -1) "
#    1091                 "if it contains a single sample."
#    1092             )
# -> 1093         raise ValueError(msg)
#    1095 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1096     raise ValueError(
#    1097         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1098         "Convert your data to numeric values explicitly instead."
#    1099     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
