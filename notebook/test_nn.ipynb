# %%
import os
import sys
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, PredefinedSplit, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from torchvision.models import resnet50
from torch.utils.data import DataLoader
from torch.utils.data import DataLoader, TensorDataset

from sklearn.model_selection import StratifiedKFold

# Add project path
project_path = os.path.abspath("../code")
sys.path.append(project_path)
from vipm_features import ResNet50FeatureExtractor

project_path = os.path.abspath("../code")  # Adatta il percorso a dove si trova il tuo progetto
sys.path.append(project_path)
project_path = os.path.abspath("../networks")  # Adatta il percorso a dove si trova il tuo progetto
sys.path.append(project_path)
from models import *
from vipm_features import *
import vipm_costants as CONST
from vipm_pipeline import *
from dataset import *
import torch

# Configure environment variable
LOKY_MAX_CPU_COUNT = 16

# %%
# Carica il file CSV
def load_csv(csv_path):
    data = pd.read_csv(csv_path, header=None, names=['image_name', 'label'])
    return data['image_name'].tolist(), data['label'].tolist()

# Carica il file compresso NPZ
def load_features(npz_path):
    data = np.load(npz_path)
    features = data['features']
    labels = data['labels']
    return features, labels

# Percorsi
csv_path = '../dataset/train_small.csv'   
csv_unlabeled = '../dataset/train_unlabeled.csv'
csv_test = '../dataset/val_info.csv'

indir = '../dataset/train_set'  # Modifica in base alla posizione delle immagini
test_dir = '../dataset/val_set'
test_degraded_dir = '../dataset/val_set_degraded'

outdir = '../features'  # Modifica in base alla posizione delle feature
os.makedirs(outdir, exist_ok=True)

# Carica le features recuperate

# 20 
npz_path = os.path.join(outdir, 'features_unlabeled_retrived.npz')
features_20, labels_20 = load_features(npz_path)

# 20 cleaned
npz_path = os.path.join(outdir, 'features_unlabeled_retrived_cleaned.npz')
features_20_cleaned, labels_20_cleaned = load_features(npz_path)

# 40
npz_path = os.path.join(outdir, 'features_unlabeled_retrived_40.npz')
features_40, labels_40 = load_features(npz_path)

# 40 cleaned
npz_path = os.path.join(outdir, 'features_unlabeled_retrived_cleaned_40.npz')
features_40_cleaned, labels_40_cleaned = load_features(npz_path)

# 80
npz_path = os.path.join(outdir, 'features_unlabeled_retrived_80.npz')
features_80, labels_80 = load_features(npz_path)

# 80 cleaned
npz_path = os.path.join(outdir, 'features_unlabeled_retrived_cleaned_80.npz')
features_80_cleaned, labels_80_cleaned = load_features(npz_path)

# feature small 
npz_path = os.path.join(outdir, 'features_small_filtered.npz')
features_small_filtered, labels_small_filtered = load_features(npz_path)

# Carica le immagini dal CSV
image_names, labels_small = load_csv(csv_path)
labels_small = np.array(labels_small)
extractor = ResNet50FeatureExtractor()
features_small, _, _ = extractor.get_features(csv=csv_path, indir=indir, outdir=outdir, normalize=True)

# Test set 
image_names_test, labels_test = load_csv(csv_test)
labels_test = np.array(labels_test)
features_test, _, _ = extractor.get_features(csv=csv_test, indir=test_dir, outdir=outdir, normalize=True)

# Test set degraded
image_names_test_degraded, labels_test_degraded = load_csv(csv_test)
labels_test_degraded = np.array(labels_test_degraded)
features_test_degraded, _, _ = extractor.get_features(csv=csv_test, indir=test_degraded_dir, outdir=outdir, normalize=True, file_name='features_test_degraded_normalized.npz')
# Out:
# Caricamento delle feature da ../features\train_small_resnet50_features_normalized.npz
# Caricamento delle feature da ../features\val_info_resnet50_features_normalized.npz
# Caricamento delle feature da ../features\features_test_degraded_normalized.npz

# %%
log_path = "results_log.csv"
log_columns = [
    "Dimension", "Model", "K", "Accuracy",  "Top-5 Accuracy",  "Top-10 Accuracy",  "Loss"
]
logs = []

# Combinazioni di dimensioni e feature
configurations = [
    {"dimension": 20, "features": features_20, "labels": labels_20, "cleaned_features": features_20_cleaned, "cleaned_labels": labels_20_cleaned},
    {"dimension": 40, "features": features_40, "labels": labels_40, "cleaned_features": features_40_cleaned, "cleaned_labels": labels_40_cleaned},
    {"dimension": 80, "features": features_80, "labels": labels_80, "cleaned_features": features_80_cleaned, "cleaned_labels": labels_80_cleaned}
]

def train_and_evaluate_neural_network_one_layer(X, y, X_test, y_test, X_test_degraded, y_test_degraded):
    one_layer_model = OneLayerNetwork(2048, 251)
    one_layer_optimizer = torch.optim.Adam(one_layer_model.parameters(), lr=0.01)
    one_layer_scheduler = torch.optim.lr_scheduler.StepLR(one_layer_optimizer, step_size=5, gamma=0.1)
    one_layer_model_option = ModelOptions(torch.nn.CrossEntropyLoss(), one_layer_optimizer, one_layer_scheduler, input_dim = 2048)
    nn = NeuralNetwork(one_layer_model, one_layer_model_option)
    
    # Split data seed 42
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
    
    # Convert to torch tensors and create datasets
    X_train_tensor = torch.FloatTensor(X_train)
    y_train_tensor = torch.LongTensor(y_train)
    X_val_tensor = torch.FloatTensor(X_val)
    y_val_tensor = torch.LongTensor(y_val)
    
    X_test_tensor = torch.FloatTensor(X_test)
    y_test_tensor = torch.LongTensor(y_test)
    X_test_degraded_tensor = torch.FloatTensor(X_test_degraded)
    y_test_degraded_tensor = torch.LongTensor(y_test_degraded)
    
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_degraded_dataset = TensorDataset(X_test_degraded_tensor, y_test_degraded_tensor)
    
    train_loader = DataLoader(train_dataset,  batch_size=one_layer_model_option.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_degraded_loader = DataLoader(test_degraded_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)

    nn.fit(train_loader, val_loader)
    loss, top1_accuracy, top5_accuracy, top10_accuracy, y_pred_top1, y_test = nn.predict(test_loader)
    loss_degraded, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, y_pred_top1_degraded, y_test_degraded = nn.predict(test_degraded_loader)
    
    return top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded


def train_and_evaluate_neural_network_classifer(X, y, X_test, y_test, X_test_degraded, y_test_degraded):
    one_layer_model = ClassifierNetwork(2048, 251)
    one_layer_optimizer = torch.optim.Adam(one_layer_model.parameters(), lr=0.01)
    one_layer_scheduler = torch.optim.lr_scheduler.StepLR(one_layer_optimizer, step_size=5, gamma=0.1)
    one_layer_model_option = ModelOptions(torch.nn.CrossEntropyLoss(), one_layer_optimizer, one_layer_scheduler, input_dim = 2048)
    nn = NeuralNetwork(one_layer_model, one_layer_model_option)
    
    # Split data seed 42
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
    
    # Convert to torch tensors and create datasets
    X_train_tensor = torch.FloatTensor(X_train)
    y_train_tensor = torch.LongTensor(y_train)
    X_val_tensor = torch.FloatTensor(X_val)
    y_val_tensor = torch.LongTensor(y_val)
    
    X_test_tensor = torch.FloatTensor(X_test)
    y_test_tensor = torch.LongTensor(y_test)
    X_test_degraded_tensor = torch.FloatTensor(X_test_degraded)
    y_test_degraded_tensor = torch.LongTensor(y_test_degraded)
    
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_degraded_dataset = TensorDataset(X_test_degraded_tensor, y_test_degraded_tensor)
    
    train_loader = DataLoader(train_dataset,  batch_size=one_layer_model_option.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)
    test_degraded_loader = DataLoader(test_degraded_dataset, batch_size=one_layer_model_option.batch_size, shuffle=True)

    nn.fit(train_loader, val_loader)
    loss, top1_accuracy, top5_accuracy, top10_accuracy, y_pred_top1, y_test = nn.predict(test_loader)
    loss_degraded, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, y_pred_top1_degraded, y_test_degraded = nn.predict(test_degraded_loader)
    
    return top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded



# Test small come baseline
for small_cleaned in [False, True]:
    print(f"Small Cleaned: {small_cleaned}")

    if small_cleaned:
        small_features = features_small_filtered
        small_labels = labels_small_filtered
    else:
        small_features = features_small
        small_labels = labels_small

    print("  Prova con modello One Layer")  
    top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_one_layer(small_features, small_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
    print(f"    Test Set One Layer: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
    print(f"    Test Set Degraded One Layer: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
    logs.append([0, "Test Set One Layer", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
    logs.append([0, "Test Set Degraded One Layer", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded]) 
    
    print("  Prova con modello Classifier")
    top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_classifer(small_features, small_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
    print(f"    Test Set Classifier: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
    print(f"    Test Set Degraded Classifier: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
    logs.append([0, "Test Set Classifier", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
    logs.append([0, "Test Set Degraded Classifier", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded])

        
# Cross-validation 80-20 e test
for config in configurations:
    dim = config["dimension"]
    print(f"Iniziando configurazione per dimensione: {dim}")

    # Combinazioni di feature tra small e dimensione specifica
    for small_cleaned in [False, True]:
        for dim_cleaned in [False, True]:

            if small_cleaned:
                small_features = features_small_filtered
                small_labels = labels_small_filtered
            else:
                small_features = features_small
                small_labels = labels_small

            if dim_cleaned:
                current_features = config["cleaned_features"]
                current_labels = config["cleaned_labels"][0]
            else:
                current_features = config["features"]
                current_labels = config["labels"][0]

            print(f"  Small Cleaned: {small_cleaned}, Dim Cleaned: {dim_cleaned}")

            # Unione delle feature
            combined_features = np.concatenate((current_features, small_features), axis=0)
            combined_labels = np.concatenate((current_labels, small_labels), axis=0)
            
            
            print("  Prova con modello One Layer")
            top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_one_layer(combined_features, combined_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
            print(f"    Test Set One Layer: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
            print(f"    Test Set Degraded One Layer: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
            logs.append([dim, "Test Set One Layer", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
            logs.append([dim, "Test Set Degraded One Layer", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded])
            
            print("  Prova con modello Classifier")
            top1_accuracy, top5_accuracy, top10_accuracy, loss, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded = train_and_evaluate_neural_network_classifer(combined_features, combined_labels, features_test, labels_test, features_test_degraded, labels_test_degraded)
            print(f"    Test Set Classifier: Accuracy={top1_accuracy}, Top-5 Accuracy={top5_accuracy}, Top-10 Accuracy={top10_accuracy}, Loss={loss}")
            print(f"    Test Set Degraded Classifier: Accuracy={top1_accuracy_degraded}, Top-5 Accuracy={top5_accuracy_degraded}, Top-10 Accuracy={top10_accuracy_degraded}, Loss={loss_degraded}")
            logs.append([dim, "Test Set Classifier", 0, top1_accuracy, top5_accuracy, top10_accuracy, loss])
            logs.append([dim, "Test Set Degraded Classifier", 0, top1_accuracy_degraded, top5_accuracy_degraded, top10_accuracy_degraded, loss_degraded])

# Salva i log in un CSV
log_df = pd.DataFrame(logs, columns=log_columns)
log_df.to_csv(log_path, index=False)
print(f"Log salvato in {log_path}")
# Out:
# Small Cleaned: False
#   Prova con modello One Layer
# Epoch 1/100:
#   Train Loss: 5.6685, Train Accuracy: 0.51%
#   Val Loss: 5.5236, Val Accuracy: 0.20%
# Epoch 2/100:
#   Train Loss: 5.5848, Train Accuracy: 0.66%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 3/100:
#   Train Loss: 5.4419, Train Accuracy: 1.31%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 4/100:
#   Train Loss: 5.3110, Train Accuracy: 1.44%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 5/100:
#   Train Loss: 5.1721, Train Accuracy: 1.81%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 6/100:
#   Train Loss: 5.0603, Train Accuracy: 2.41%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 7/100:
#   Train Loss: 5.0432, Train Accuracy: 2.59%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 8/100:
#   Train Loss: 5.0114, Train Accuracy: 2.77%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 9/100:
#   Train Loss: 4.9695, Train Accuracy: 2.37%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 10/100:
#   Train Loss: 4.9731, Train Accuracy: 2.55%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
# Epoch 11/100:
#   Train Loss: 4.9680, Train Accuracy: 2.66%
#   Val Loss: 5.5281, Val Accuracy: 0.20%
#
# Early stopping triggered. Stopping training.
#     Test Set One Layer: Accuracy=0.004919126229781558, Top-5 Accuracy=0.02051025512756378, Top-10 Accuracy=0.04752376188094047, Loss=5.524290482203166
#     Test Set Degraded One Layer: Accuracy=0.004752376188094047, Top-5 Accuracy=0.020343505085876273, Top-10 Accuracy=0.04527263631815908, Loss=5.524592638015747
#   Prova con modello Classifier
# Epoch 1/100:
#   Train Loss: 5.1945, Train Accuracy: 2.79%
#   Val Loss: 5.5250, Val Accuracy: 0.20%
# Epoch 2/100:
#   Train Loss: 3.7380, Train Accuracy: 25.34%
#   Val Loss: 5.4363, Val Accuracy: 6.37%
# Epoch 3/100:
#   Train Loss: 2.8848, Train Accuracy: 37.16%
#   Val Loss: 5.2348, Val Accuracy: 10.96%
# Epoch 4/100:
#   Train Loss: 2.3684, Train Accuracy: 46.06%
#   Val Loss: 5.0074, Val Accuracy: 12.95%
# Epoch 5/100:
#   Train Loss: 1.9680, Train Accuracy: 54.32%
#   Val Loss: 4.7668, Val Accuracy: 15.14%
# Epoch 6/100:
#   Train Loss: 1.6572, Train Accuracy: 60.65%
#   Val Loss: 4.5411, Val Accuracy: 18.92%
# Epoch 7/100:
#   Train Loss: 1.5872, Train Accuracy: 62.22%
#   Val Loss: 4.4075, Val Accuracy: 21.12%
# Epoch 8/100:
#   Train Loss: 1.5075, Train Accuracy: 65.65%
#   Val Loss: 4.2767, Val Accuracy: 21.71%
# Epoch 9/100:
#   Train Loss: 1.4226, Train Accuracy: 67.99%
#   Val Loss: 4.1521, Val Accuracy: 22.31%
# Epoch 10/100:
#   Train Loss: 1.3716, Train Accuracy: 69.99%
#   Val Loss: 4.0376, Val Accuracy: 22.31%
# Epoch 11/100:
#   Train Loss: 4.3101, Train Accuracy: 12.23%
#   Val Loss: 5.5261, Val Accuracy: 0.56%
# Epoch 2/100:
#   Train Loss: 2.8787, Train Accuracy: 29.18%
#   Val Loss: 5.0185, Val Accuracy: 14.79%
# Epoch 3/100:
#   Train Loss: 2.5079, Train Accuracy: 35.21%
#   Val Loss: 4.2878, Val Accuracy: 19.13%
# Epoch 4/100:
#   Train Loss: 2.2381, Train Accuracy: 39.86%
#   Val Loss: 3.7833, Val Accuracy: 18.99%
# Epoch 5/100:
#   Train Loss: 2.0337, Train Accuracy: 43.06%
#   Val Loss: 3.4013, Val Accuracy: 22.56%
# Epoch 6/100:
#   Train Loss: 1.8557, Train Accuracy: 47.09%
#   Val Loss: 3.2539, Val Accuracy: 22.21%
# Epoch 7/100:
#   Train Loss: 1.8089, Train Accuracy: 48.52%
#   Val Loss: 3.0349, Val Accuracy: 24.74%
# Epoch 8/100:
#   Train Loss: 1.7521, Train Accuracy: 49.12%
#   Val Loss: 2.9692, Val Accuracy: 25.37%
# Epoch 9/100:
#   Train Loss: 1.7514, Train Accuracy: 48.80%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 10/100:
#   Train Loss: 1.7169, Train Accuracy: 49.56%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 11/100:
#   Train Loss: 1.6885, Train Accuracy: 50.35%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 12/100:
#   Train Loss: 1.6713, Train Accuracy: 50.21%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 13/100:
#   Train Loss: 1.6846, Train Accuracy: 50.16%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 14/100:
#   Train Loss: 1.6707, Train Accuracy: 50.29%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 15/100:
#   Train Loss: 1.6763, Train Accuracy: 50.64%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 16/100:
#   Train Loss: 1.6663, Train Accuracy: 50.74%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 17/100:
#   Train Loss: 1.6798, Train Accuracy: 50.08%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
# Epoch 18/100:
#   Train Loss: 1.6787, Train Accuracy: 50.76%
#   Val Loss: 2.9881, Val Accuracy: 25.09%
#
# Early stopping triggered. Stopping training.
#     Test Set Classifier: Accuracy=0.26221444055361015, Top-5 Accuracy=0.5207603801900951, Top-10 Accuracy=0.6370685342671336, Loss=3.647749900817871
#     Test Set Degraded Classifier: Accuracy=0.1765049191262298, Top-5 Accuracy=0.3752709688177422, Top-10 Accuracy=0.47832249458062365, Loss=4.822172164916992
#   Small Cleaned: True, Dim Cleaned: True
#   Prova con modello One Layer
# Epoch 1/100:
#   Train Loss: 5.5189, Train Accuracy: 0.68%
#   Val Loss: 5.5250, Val Accuracy: 0.42%
# Epoch 2/100:
#   Train Loss: 5.0123, Train Accuracy: 2.06%
#   Val Loss: 5.3604, Val Accuracy: 1.54%
#   Val Loss: 3.1754, Val Accuracy: 24.78%
# Epoch 6/100:
#   Train Loss: 2.3467, Train Accuracy: 36.72%
#   Val Loss: 3.1963, Val Accuracy: 25.54%
# Epoch 7/100:
#   Train Loss: 2.2313, Train Accuracy: 38.55%
#   Val Loss: 3.1575, Val Accuracy: 25.54%
# Epoch 8/100:
#   Train Loss: 2.1789, Train Accuracy: 39.07%
#   Val Loss: 2.9469, Val Accuracy: 27.01%
# Epoch 9/100:
#   Train Loss: 2.1611, Train Accuracy: 39.48%
#   Val Loss: 2.9239, Val Accuracy: 27.01%
# Epoch 10/100:
#   Train Loss: 2.0990, Train Accuracy: 40.04%
#   Val Loss: 2.8997, Val Accuracy: 26.81%
# Epoch 11/100:
#   Train Loss: 2.0909, Train Accuracy: 40.58%
#   Val Loss: 2.8772, Val Accuracy: 26.73%
# Epoch 12/100:
#   Train Loss: 2.1120, Train Accuracy: 40.12%
#   Val Loss: 2.9599, Val Accuracy: 26.73%
# Epoch 13/100:
#   Train Loss: 2.0977, Train Accuracy: 40.21%
#   Val Loss: 2.9247, Val Accuracy: 26.73%
# Epoch 14/100:
#   Train Loss: 2.0936, Train Accuracy: 40.43%
#   Val Loss: 2.9563, Val Accuracy: 26.73%
# Epoch 15/100:
#   Train Loss: 2.0810, Train Accuracy: 40.48%
#   Val Loss: 2.9379, Val Accuracy: 26.73%
# Epoch 16/100:
#   Train Loss: 2.0879, Train Accuracy: 40.65%
#   Val Loss: 2.9089, Val Accuracy: 26.73%
# Epoch 17/100:
#   Train Loss: 2.0934, Train Accuracy: 40.54%
#   Val Loss: 2.8688, Val Accuracy: 26.73%
# Epoch 18/100:
#   Train Loss: 2.1117, Train Accuracy: 40.35%
#   Val Loss: 2.9122, Val Accuracy: 26.49%
# Epoch 19/100:
#   Train Loss: 2.1014, Train Accuracy: 40.15%
#   Val Loss: 2.9182, Val Accuracy: 26.49%
# Epoch 20/100:
#   Train Loss: 2.0897, Train Accuracy: 40.37%
#   Val Loss: 2.9325, Val Accuracy: 26.49%
# Epoch 21/100:
#   Train Loss: 2.0976, Train Accuracy: 40.46%
#   Val Loss: 2.9707, Val Accuracy: 26.49%
# Epoch 22/100:
#   Train Loss: 2.0749, Train Accuracy: 40.22%
#   Val Loss: 2.9280, Val Accuracy: 26.49%
# Epoch 23/100:
#   Train Loss: 2.1002, Train Accuracy: 40.51%
#   Val Loss: 2.9141, Val Accuracy: 26.49%
# Epoch 24/100:
#   Train Loss: 2.0982, Train Accuracy: 40.51%
#   Val Loss: 2.9412, Val Accuracy: 26.49%
# Epoch 25/100:
#   Train Loss: 2.0885, Train Accuracy: 40.42%
#   Val Loss: 2.9147, Val Accuracy: 26.49%
# Epoch 26/100:
#   Train Loss: 2.0889, Train Accuracy: 40.24%
#   Val Loss: 2.9205, Val Accuracy: 26.49%
# Epoch 27/100:
#   Train Loss: 2.0988, Train Accuracy: 40.53%
#   Val Loss: 2.9532, Val Accuracy: 26.49%
#
# Early stopping triggered. Stopping training.
# Epoch 21/100:
#   Train Loss: 3.8438, Train Accuracy: 12.18%
#   Val Loss: 3.7083, Val Accuracy: 14.15%
# Epoch 22/100:
#   Train Loss: 3.8363, Train Accuracy: 12.13%
#   Val Loss: 3.7034, Val Accuracy: 14.15%
# Epoch 23/100:
#   Train Loss: 3.8426, Train Accuracy: 11.87%
#   Val Loss: 3.7082, Val Accuracy: 14.15%
# Epoch 24/100:
#   Train Loss: 3.8392, Train Accuracy: 11.88%
#   Val Loss: 3.7532, Val Accuracy: 14.15%
# Epoch 25/100:
#   Train Loss: 3.8380, Train Accuracy: 12.11%
#   Val Loss: 3.7285, Val Accuracy: 14.15%
#
# Early stopping triggered. Stopping training.
#     Test Set One Layer: Accuracy=0.13340003335000833, Top-5 Accuracy=0.34725696181424043, Top-10 Accuracy=0.48257462064365514, Loss=4.112460136413574
#     Test Set Degraded One Layer: Accuracy=0.0936301484075371, Top-5 Accuracy=0.2567116891779223, Top-10 Accuracy=0.3635150908787727, Loss=4.729555050532023
#   Prova con modello Classifier
# Epoch 1/100:
#   Train Loss: 4.0245, Train Accuracy: 14.25%
#   Val Loss: 5.5256, Val Accuracy: 0.49%
# Epoch 2/100:
#   Train Loss: 2.8727, Train Accuracy: 27.55%
#   Val Loss: 4.6887, Val Accuracy: 15.59%
# Epoch 3/100:
#   Train Loss: 2.6007, Train Accuracy: 31.02%
#   Val Loss: 3.8762, Val Accuracy: 16.82%
# Epoch 4/100:
#   Train Loss: 2.4194, Train Accuracy: 33.69%
#   Val Loss: 3.5007, Val Accuracy: 19.70%
# Epoch 5/100:
#   Train Loss: 2.2875, Train Accuracy: 35.63%
#   Val Loss: 3.3110, Val Accuracy: 20.36%
# Epoch 6/100:
#   Train Loss: 2.1185, Train Accuracy: 38.92%
#   Val Loss: 3.2949, Val Accuracy: 19.79%
# Epoch 7/100:
#   Train Loss: 2.0500, Train Accuracy: 39.80%
#   Val Loss: 3.1494, Val Accuracy: 20.53%
# Epoch 8/100:
#   Train Loss: 2.0370, Train Accuracy: 40.19%
#   Val Loss: 3.2130, Val Accuracy: 20.28%
# Epoch 9/100:
#   Train Loss: 2.0121, Train Accuracy: 40.39%
#   Val Loss: 3.1860, Val Accuracy: 20.28%
# Epoch 10/100:
#   Train Loss: 1.9948, Train Accuracy: 40.64%
#   Val Loss: 3.1652, Val Accuracy: 20.28%
# Epoch 11/100:
#   Train Loss: 1.9740, Train Accuracy: 40.83%
#   Val Loss: 3.2168, Val Accuracy: 20.28%
# Epoch 12/100:
#   Train Loss: 1.9730, Train Accuracy: 41.11%
#   Val Loss: 3.2416, Val Accuracy: 20.28%
# Epoch 13/100:
#   Train Loss: 1.9713, Train Accuracy: 41.10%
#   Val Loss: 3.2441, Val Accuracy: 20.28%
# Epoch 14/100:
#   Train Loss: 1.9624, Train Accuracy: 41.28%
#   Val Loss: 3.1705, Val Accuracy: 20.28%
# Epoch 15/100:
#   Train Loss: 1.9689, Train Accuracy: 41.08%
#   Val Loss: 3.1568, Val Accuracy: 20.28%
# Epoch 16/100:
#   Train Loss: 1.9639, Train Accuracy: 41.18%
#   Val Loss: 3.1745, Val Accuracy: 20.28%
# Epoch 17/100:
#   Train Loss: 1.9681, Train Accuracy: 41.09%
#   Val Loss: 3.1744, Val Accuracy: 20.28%
#
# Early stopping triggered. Stopping training.
#     Test Set Classifier: Accuracy=0.2560446890111723, Top-5 Accuracy=0.517342004335501, Top-10 Accuracy=0.6339002834750709, Loss=3.904000918070475
#     Test Set Degraded Classifier: Accuracy=0.1774220443555111, Top-5 Accuracy=0.37201934300483575, Top-10 Accuracy=0.4770718692679673, Loss=5.305070638656616
#   Small Cleaned: True, Dim Cleaned: True
#   Prova con modello One Layer
# Epoch 1/100:
#   Train Loss: 5.3535, Train Accuracy: 1.57%
#   Val Loss: 5.5276, Val Accuracy: 0.16%
# Epoch 2/100:
#   Train Loss: 4.6909, Train Accuracy: 3.69%
#   Val Loss: 5.0925, Val Accuracy: 1.60%
# Epoch 3/100:
#   Train Loss: 4.3799, Train Accuracy: 5.59%
#   Val Loss: 4.6197, Val Accuracy: 3.50%
# Epoch 4/100:
#   Train Loss: 4.1658, Train Accuracy: 7.54%
#   Val Loss: 4.2393, Val Accuracy: 6.75%
# Epoch 5/100:
#   Train Loss: 3.9981, Train Accuracy: 9.30%
#   Val Loss: 3.9695, Val Accuracy: 10.24%
# Epoch 6/100:
#   Train Loss: 3.8782, Train Accuracy: 11.15%
#   Val Loss: 3.8316, Val Accuracy: 12.42%
# Epoch 7/100:
#   Train Loss: 3.8390, Train Accuracy: 11.85%
#   Val Loss: 3.7064, Val Accuracy: 14.64%
# Epoch 8/100:
#   Train Loss: 3.8020, Train Accuracy: 12.33%
#   Val Loss: 3.7196, Val Accuracy: 15.51%
# Epoch 9/100:
#   Train Loss: 3.7879, Train Accuracy: 12.45%
#   Val Loss: 3.6719, Val Accuracy: 15.51%
# Epoch 10/100:
#   Train Loss: 3.7573, Train Accuracy: 12.71%
#   Val Loss: 3.6985, Val Accuracy: 16.21%
# Epoch 11/100:
#   Train Loss: 3.7466, Train Accuracy: 12.86%
#   Val Loss: 3.6502, Val Accuracy: 16.21%
# Epoch 12/100:
#   Train Loss: 3.7460, Train Accuracy: 12.87%
#   Val Loss: 3.6221, Val Accuracy: 16.17%
# Epoch 13/100:
#   Train Loss: 3.7443, Train Accuracy: 13.52%
#   Val Loss: 3.6153, Val Accuracy: 16.21%
# Epoch 14/100:
#   Train Loss: 3.7426, Train Accuracy: 13.14%
#   Val Loss: 3.6396, Val Accuracy: 16.41%
# Epoch 15/100:
#   Train Loss: 3.7387, Train Accuracy: 13.09%
#   Val Loss: 3.6348, Val Accuracy: 16.41%
# Epoch 16/100:
#   Train Loss: 3.7273, Train Accuracy: 13.10%
#   Val Loss: 3.5821, Val Accuracy: 16.41%
# Epoch 17/100:
#   Train Loss: 3.7323, Train Accuracy: 13.46%
#   Val Loss: 3.6229, Val Accuracy: 16.50%
# Epoch 18/100:
#   Train Loss: 3.7326, Train Accuracy: 13.27%
#   Val Loss: 3.6076, Val Accuracy: 16.50%
#     Test Set Degraded One Layer: Accuracy=0.0912122728030682, Top-5 Accuracy=0.2563781890945473, Top-10 Accuracy=0.36551609137902286, Loss=4.708133618036906
#   Prova con modello Classifier
# Epoch 1/100:
#   Train Loss: 3.9227, Train Accuracy: 15.73%
#   Val Loss: 5.5263, Val Accuracy: 0.41%
# Epoch 2/100:
#   Train Loss: 2.7445, Train Accuracy: 29.49%
#   Val Loss: 4.6051, Val Accuracy: 14.93%
# Epoch 3/100:
#   Train Loss: 2.4553, Train Accuracy: 33.54%
#   Val Loss: 3.7569, Val Accuracy: 17.69%
# Epoch 4/100:
#   Train Loss: 2.2781, Train Accuracy: 36.25%
#   Val Loss: 3.2565, Val Accuracy: 21.47%
# Epoch 5/100:
#   Train Loss: 2.1559, Train Accuracy: 38.22%
#   Val Loss: 3.1601, Val Accuracy: 22.58%
# Epoch 6/100:
#   Train Loss: 1.9770, Train Accuracy: 41.68%
#   Val Loss: 3.1281, Val Accuracy: 23.36%
# Epoch 7/100:
#   Train Loss: 1.9123, Train Accuracy: 42.75%
#   Val Loss: 2.9503, Val Accuracy: 23.32%
# Epoch 8/100:
#   Train Loss: 1.8885, Train Accuracy: 42.75%
#   Val Loss: 2.9947, Val Accuracy: 23.69%
# Epoch 9/100:
#   Train Loss: 1.8716, Train Accuracy: 43.09%
#   Val Loss: 2.8945, Val Accuracy: 23.69%
# Epoch 10/100:
#   Train Loss: 1.8582, Train Accuracy: 43.11%
#   Val Loss: 2.9812, Val Accuracy: 23.08%
# Epoch 11/100:
#   Train Loss: 1.8317, Train Accuracy: 43.79%
#   Val Loss: 2.9381, Val Accuracy: 23.08%
# Epoch 12/100:
#   Train Loss: 1.8264, Train Accuracy: 43.99%
#   Val Loss: 3.0101, Val Accuracy: 23.08%
# Epoch 13/100:
#   Train Loss: 1.8275, Train Accuracy: 44.11%
#   Val Loss: 3.0474, Val Accuracy: 23.08%
# Epoch 14/100:
#   Train Loss: 1.8273, Train Accuracy: 43.76%
#   Val Loss: 2.9941, Val Accuracy: 23.08%
# Epoch 15/100:
#   Train Loss: 1.8242, Train Accuracy: 44.07%
#   Val Loss: 2.9934, Val Accuracy: 23.08%
# Epoch 16/100:
#   Train Loss: 1.8246, Train Accuracy: 43.87%
#   Val Loss: 2.9736, Val Accuracy: 23.08%
# Epoch 17/100:
#   Train Loss: 1.8230, Train Accuracy: 43.92%
#   Val Loss: 3.0017, Val Accuracy: 23.08%
# Epoch 18/100:
#   Train Loss: 1.8221, Train Accuracy: 43.82%
#   Val Loss: 2.9768, Val Accuracy: 23.08%
# Epoch 19/100:
#   Train Loss: 1.8197, Train Accuracy: 43.83%
#   Val Loss: 3.0357, Val Accuracy: 23.08%
#
# Early stopping triggered. Stopping training.
#     Test Set Classifier: Accuracy=0.2568784392196098, Top-5 Accuracy=0.5084208771052193, Top-10 Accuracy=0.6283141570785392, Loss=4.0188759962717695
#     Test Set Degraded Classifier: Accuracy=0.1727530431882608, Top-5 Accuracy=0.3699349674837419, Top-10 Accuracy=0.4737368684342171, Loss=5.393442392349243
# Log salvato in results_log.csv
